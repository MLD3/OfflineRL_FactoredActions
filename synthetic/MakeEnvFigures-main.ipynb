# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as mpath

# %%
import matplotlib
matplotlib.rcParams['text.latex.preamble'] = r"""
\usepackage{bm}
"""
matplotlib.rcParams.update({
    'text.usetex': True,
    # 'font.serif': 'Computer Modern Roman',
    # "font.family": "serif",
    "font.serif": ['Palatino'],
    'font.sans-serif': ['FreeSans'],
    # 'text.latex.unicode': True,
})
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ## Chain 2D

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

s_offset = 0.0
plt.gca().annotate(r'$s_{0,0}$', (0+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{0,1}$', (0+s_offset, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,0}$', (1+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,1}$', (1+s_offset, 1), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sx, sy = 0, 0
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 0, 1
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 1, 0
a = patches.FancyArrowPatch((sx-offset, sy+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx, sy-offset*4), (sx, sy-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy-offset*3), (sx, sy-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (sx+offset*3, sy-offset*3), (sx+offset*4, sy), (sx+offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*3, sy-offset), (sx+offset*1.25, sy), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


plt.savefig('figures/chain2d_plain.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2.5, 2.5))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.scatter(-0.75, 1.75, s=200, facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-1.25, 1.5)
plt.ylim(-0.5, 2.25)

s_offset = 0.02
plt.gca().annotate(r'$s_{0,0}$', (0, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{0,1}$', (0, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,0}$', (1, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,1}$', (1, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r"$\tilde{s}_{0,1}$", (-0.75, 1.75), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sx, sy = 0, 0
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 0, 1
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 1, 0
a = patches.FancyArrowPatch((sx-offset, sy+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx, sy-offset*4), (sx, sy-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy-offset*3), (sx, sy-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (sx+offset*3, sy-offset*3), (sx+offset*4, sy), (sx+offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*3, sy-offset), (sx+offset*1.25, sy), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = -0.75, 1.75
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1, 1+offset+0.05), connectionstyle="arc3,rad=-.5", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (0, 1.25), (0.5, 1.5), (1-offset-0.05, 1+offset+0.05)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((0.725, 1.25), (1-offset-0.05, 1+offset+0.05), connectionstyle="arc3,rad=-0.1", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

# split transition arrow
a = patches.FancyArrowPatch((-offset-0.05, offset+0.1), (-0.75, 1.75-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)



plt.gca().annotate('$+1$', (0.5, -offset*2.2), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+1$', (-0.15, 0.3), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1-offset*1.3, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1+offset*2, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.5, 1-offset*2), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.5, 1+offset*1.3), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+2$', (0.5-offset, 0.5-offset),  c='r', ha='left',  va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.25, 1.4), c='r', ha='right', va='bottom', fontsize=6)
plt.gca().annotate('$+1$', (0.25, 1.95), c='r', ha='right', va='top', fontsize=6)

plt.gca().annotate('$p$', (-0.15, 0.5), c='g', ha='left', va='bottom', fontsize=6)
plt.gca().annotate('$(1-p)$', (-0.35, 0.5), c='g', ha='right', va='bottom', fontsize=6)

plt.savefig('figures/chain2d_abstract.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2.75, 2.75))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.scatter(-0.75, 1.75, s=200, facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-1.25, 1.5)
plt.ylim(-0.5, 2.25)

s_offset = 0.0
plt.gca().annotate(r'$s_{0,0}$', (0+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{0,1}$', (0+s_offset, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,0}$', (1+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,1}$', (1+s_offset, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r"$\tilde{s}_{0,1}$", (-0.75+s_offset, 1.75), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1



sx, sy = 0, 0
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 0, 1
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 1, 0
a = patches.FancyArrowPatch((sx-offset, sy+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx, sy-offset*4), (sx, sy-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy-offset*3), (sx, sy-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (sx+offset*3, sy-offset*3), (sx+offset*4, sy), (sx+offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*3, sy-offset), (sx+offset*1.25, sy), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = -0.75, 1.75
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1, 1+offset+0.05), connectionstyle="arc3,rad=-.5", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (0, 1.25), (0.5, 1.5), (1-offset-0.05, 1+offset+0.05)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=1.8, color='b')
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((0.725, 1.25), (1-offset-0.05, 1+offset+0.05), connectionstyle="arc3,rad=-0.1", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


a = patches.FancyArrowPatch((-offset-0.05, offset+0.1), (-0.75, 1.75-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (0.5, -offset*2.2), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+1$', (-0.15, 0.3), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1-offset*1.3, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1+offset*2, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.5, 1-offset*2), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.5, 1+offset*1.3), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+2$', (0.5-offset, 0.5-offset),  c='r', ha='left',  va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.25, 1.4), c='r', ha='right', va='bottom', fontsize=6)
plt.gca().annotate('$+1$', (0.25, 1.95), c='r', ha='right', va='top', fontsize=6)

plt.gca().annotate('$p$', (-0.15, 0.5), c='g', ha='left', va='bottom', fontsize=6)
plt.gca().annotate('$(1-p)$', (-0.35, 0.5), c='g', ha='right', va='bottom', fontsize=6)


plt.savefig('figures/chain2d_abstract.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(3.75, 3.75))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.scatter(-0.75, 1.75, s=200, facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-2.25, 1.5)
plt.ylim(-1.5, 2.25)

s_offset = 0.0
plt.gca().annotate(r'$s_{0,0}$', (0+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{0,1}$', (0+s_offset, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,0}$', (1+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,1}$', (1+s_offset, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r"$\tilde{s}_{0,1}$", (-0.75+s_offset, 1.75), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1



sx, sy = 0, 0
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 0, 1
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 1, 0
a = patches.FancyArrowPatch((sx-offset, sy+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx, sy-offset*4), (sx, sy-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy-offset*3), (sx, sy-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (sx+offset*3, sy-offset*3), (sx+offset*4, sy), (sx+offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*3, sy-offset), (sx+offset*1.25, sy), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = -0.75, 1.75
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1, 1+offset+0.05), connectionstyle="arc3,rad=-.5", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (0, 1.25), (0.5, 1.5), (1-offset-0.05, 1+offset+0.05)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=1.8, color='b')
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((0.725, 1.25), (1-offset-0.05, 1+offset+0.05), connectionstyle="arc3,rad=-0.1", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


a = patches.FancyArrowPatch((-offset-0.05, offset+0.1), (-0.75, 1.75-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (0.5, -offset*2.2), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+1$', (-0.15, 0.3), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1-offset*1.3, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1+offset*2, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.5, 1-offset*2), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.5, 1+offset*1.3), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+2$', (0.5-offset, 0.5-offset),  c='r', ha='left',  va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.25, 1.4), c='r', ha='right', va='bottom', fontsize=6)
plt.gca().annotate('$+1$', (0.25, 1.95), c='r', ha='right', va='top', fontsize=6)

plt.gca().annotate('$p$', (-0.15, 0.5), c='g', ha='left', va='bottom', fontsize=6)
plt.gca().annotate('$(1-p)$', (-0.35, 0.5), c='g', ha='right', va='bottom', fontsize=6)



## Horizontal Chain
sub_offset = -0.8

plt.scatter(0, sub_offset, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, sub_offset, s=200, facecolors='none', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$z_{0,?}$', (0, sub_offset), fontsize=8, ha='center', va='center')
plt.gca().annotate('$z_{1,?}$', (1, sub_offset), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sx, sy = 0, sub_offset
a = patches.FancyArrowPatch((sx+offset*1.3, sy), (1-offset*1.25, sy), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx-offset*5, sy), (sx-offset*1.2, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*1.8, sy+offset*1.5), (sx-offset*0.8, sy+offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 1, 0.08+sub_offset
a = patches.PathPatch(mpath.Path([(sx-offset*0.5, sy+offset*0.5), (sx-offset*3, sy+offset*3), (sx-offset*5, sy), (sx-offset, sy+offset*0.1)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*2, sy+offset*1.45), (sx-offset*0.5, sy+offset*0.5), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset*0.5, sy+offset*0.5), (sx+offset*3, sy+offset*3), (sx+offset*5, sy), (sx+offset, sy+offset*0.1)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=1.8, color='b')
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*2, sy+offset*1.45), (sx+offset*0.5, sy+offset*0.5), connectionstyle="arc3,rad=.2", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate('$+1$', (0.45, sub_offset-0.03), c='r', ha='center', va='top', fontsize=6)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)


## Vertical Chain
sub_offset = -1.5

plt.scatter(sub_offset, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(sub_offset, 1, s=200, facecolors='none', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$z_{?,0}$', (sub_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate('$z_{?,1}$', (sub_offset, 1), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sx, sy = sub_offset, 0
a = patches.FancyArrowPatch((sx, sy+offset*1.3), (sx, 1-offset*1.25), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx, sy-offset*5), (sx, sy-offset*1.2)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*1.5, sy-offset*1.8), (sx-offset*0.8, sy-offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (sub_offset-0.03, 0.45), c='r', ha='right', va='center', fontsize=6)

sx, sy = 0.08+sub_offset, 1
a = patches.PathPatch(mpath.Path([(sx+offset*0.5, sy-offset*0.5), (sx+offset*3, sy-offset*3), (sx, sy-offset*5), (sx+offset*0.1, sy-offset)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=1.8, color='b')
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*1.45, sy-offset*2), (sx+offset*0.5, sy-offset*0.5), connectionstyle="arc3,rad=.2", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset*0.5, sy+offset*0.5), (sx+offset*3, sy+offset*3), (sx, sy+offset*5), (sx+offset*0.1, sy+offset)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*1.45, sy+offset*2), (sx+offset*0.5, sy+offset*0.5), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)

plt.plot([-1.15, -1.15], [-1, 2], c='gray', lw=0.5)
plt.plot([-1.75, 1.5], [-0.5, -0.5], c='gray', lw=0.5)
plt.plot([-1.15, -1.65], [-0.5, -0.95], c='gray', lw=0.5)
# plt.gca().annotate(r'$\mathcal{M}_{\mathrm{x}}$', (-1.45, -0.85), ha='center', va='center', fontsize=9)
# plt.gca().annotate(r'$\mathcal{M}_{\mathrm{y}}$', (-1.65, -0.65), ha='center', va='center', fontsize=9)
plt.gca().annotate(r'$\phi_{\mathrm{x}}$', (-1.35, -0.85), ha='center', va='center', fontsize=9)
plt.gca().annotate(r'$\phi_{\mathrm{y}}$', (-1.55, -0.65), ha='center', va='center', fontsize=9)

plt.gca().annotate('Original MDP', (1.5, 1.5), ha='center', va='center', fontsize=9)
plt.gca().annotate('Abstract MDP \nin y-direction', (-1.75, 1.4), ha='center', va='bottom', fontsize=9)
plt.gca().annotate('Abstract MDP \nin x-direction', (1.5, -0.85), ha='left', va='center', fontsize=9, clip_on=False)

plt.savefig('figures/chain2d_abstract.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2.75, 2.75))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-1, 1.5)
plt.ylim(-1, 1.5)

s_offset = 0.0
plt.gca().annotate(r'$s_{0,0}$', (0+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{0,1}$', (0+s_offset, 1), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,0}$', (1+s_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate(r'$s_{1,1}$', (1+s_offset, 1), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1



sx, sy = 0, 0
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 0, 1
# a = patches.FancyArrowPatch((sx+offset, sy+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
# plt.gca().add_patch(a)

a = patches.PathPatch(mpath.Path([(sx+offset, sy+offset), (sx+offset*3, sy+offset*3), (sx+offset*4, sy), (sx+offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*3, sy+offset), (sx+offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

a = patches.FancyArrowPatch((sx+offset, sy-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx-offset*4, sy), (sx-offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*3, sy-offset), (sx-offset*1.25, sy), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx, sy+offset*4), (sx, sy+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy+offset*3), (sx, sy+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 1, 0
a = patches.FancyArrowPatch((sx-offset, sy+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset, sy+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx, sy-offset*4), (sx, sy-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset, sy-offset*3), (sx, sy-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset, sy-offset), (sx+offset*3, sy-offset*3), (sx+offset*4, sy), (sx+offset*1.5, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*3, sy-offset), (sx+offset*1.25, sy), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate('$+1$', (0.5, -offset*2.2), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+1$', (-0.15, 0.3), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1-offset*1.3, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (1+offset*2, 0.5), c='r', ha='left', va='top', fontsize=6)
plt.gca().annotate('$+1$', (0.5, 1-offset*2), c='r', ha='right', va='top', fontsize=6)
# plt.gca().annotate('$+1$', (0.5, 1+offset*1.3), c='r', ha='right', va='top', fontsize=6)
plt.gca().annotate('$+2$', (0.5-offset, 0.5-offset),  c='r', ha='left',  va='top', fontsize=6)

plt.gca().annotate('$(1-\gamma)$', (0.5, 1.25), c='r', ha='right', va='bottom', fontsize=6)


## Horizontal Chain
sub_offset = -0.8

plt.scatter(0, sub_offset, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, sub_offset, s=200, facecolors='none', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$z_{0,?}$', (0, sub_offset), fontsize=8, ha='center', va='center')
plt.gca().annotate('$z_{1,?}$', (1, sub_offset), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sx, sy = 0, sub_offset
a = patches.FancyArrowPatch((sx+offset*1.3, sy), (1-offset*1.25, sy), connectionstyle="arc3,rad=0", alpha=1, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy+offset), (sx-offset*3, sy+offset*3), (sx-offset*5, sy), (sx-offset*1.2, sy)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=1)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*1.8, sy+offset*1.5), (sx-offset*0.8, sy+offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', alpha=1, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sx, sy = 1, 0.08+sub_offset
a = patches.PathPatch(mpath.Path([(sx-offset*0.5, sy+offset*0.5), (sx-offset*3, sy+offset*3), (sx-offset*5, sy), (sx-offset, sy+offset*0.1)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*2, sy+offset*1.45), (sx-offset*0.5, sy+offset*0.5), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset*0.5, sy+offset*0.5), (sx+offset*3, sy+offset*3), (sx+offset*5, sy), (sx+offset, sy+offset*0.1)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=1.8, color='b')
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*2, sy+offset*1.45), (sx+offset*0.5, sy+offset*0.5), connectionstyle="arc3,rad=.2", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate('$+1$', (0.45, sub_offset-0.03), c='r', ha='left', va='top', fontsize=6)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)


## Vertical Chain
sub_offset = -0.8

plt.scatter(sub_offset, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(sub_offset, 1, s=200, facecolors='none', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$z_{?,0}$', (sub_offset, 0), fontsize=8, ha='center', va='center')
plt.gca().annotate('$z_{?,1}$', (sub_offset, 1), fontsize=8, ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sx, sy = sub_offset, 0
a = patches.FancyArrowPatch((sx, sy+offset*1.3), (sx, 1-offset*1.25), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx-offset, sy-offset), (sx-offset*3, sy-offset*3), (sx, sy-offset*5), (sx, sy-offset*1.2)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx-offset*1.5, sy-offset*1.8), (sx-offset*0.8, sy-offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (sub_offset-0.03, 0.45), c='r', ha='right', va='center', fontsize=6)

sx, sy = 0.08+sub_offset, 1
a = patches.PathPatch(mpath.Path([(sx+offset*0.5, sy-offset*0.5), (sx+offset*3, sy-offset*3), (sx, sy-offset*5), (sx+offset*0.1, sy-offset)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8, alpha=0.3)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*1.45, sy-offset*2), (sx+offset*0.5, sy-offset*0.5), connectionstyle="arc3,rad=.2", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sx+offset*0.5, sy+offset*0.5), (sx+offset*3, sy+offset*3), (sx, sy+offset*5), (sx+offset*0.1, sy+offset)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=1.8, color='b')
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sx+offset*1.45, sy+offset*2), (sx+offset*0.5, sy+offset*0.5), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)

plt.plot([-0.5, -0.5], [-1, 1.5], c='gray', lw=0.5)
plt.plot([-1, 1.5], [-0.5, -0.5], c='gray', lw=0.5)
plt.plot([-0.5, -0.95], [-0.5, -0.95], c='gray', lw=0.5)
plt.gca().annotate(r'$\phi_{\mathrm{x}}$', (-0.65, -0.85), ha='center', va='center', fontsize=9)
plt.gca().annotate(r'$\phi_{\mathrm{y}}$', (-0.85, -0.65), ha='center', va='center', fontsize=9)

plt.gca().annotate('(c)', (0.25, -0.65), c='blue', ha='center', va='center', fontsize=9)
plt.gca().add_patch(patches.Rectangle((-0.4, -1), 0.75, 0.45, edgecolor='none', facecolor='blue', alpha=0.2, zorder=0, clip_on=False))

plt.gca().annotate('(a)', (0.5, 0.95), c='g', ha='center', va='center', fontsize=9)
plt.gca().add_patch(patches.Rectangle((0.1, 0.85), 0.5, 0.35, edgecolor='none', facecolor='g', alpha=0.2, zorder=0, clip_on=False))

plt.gca().annotate('(b)', (0.7, 1.3), c='r', ha='center', va='center', fontsize=9)
plt.gca().add_patch(patches.Rectangle((0.1, 1.2), 0.75, 0.2, edgecolor='none', facecolor='r', alpha=0.2, zorder=0, clip_on=False))

plt.savefig('figures/chain2d_necessary.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ## Bandits

# %%
import matplotlib
matplotlib.rcParams['text.latex.preamble'] = r"""
\usepackage{bm}
"""
matplotlib.rcParams.update({
    'text.usetex': True,
    'font.serif': 'Computer Modern Roman',
    # "font.family": "serif",
    # "font.serif": ['Palatino'],
    'font.sans-serif': ['FreeSans'],
    # 'text.latex.unicode': True,
})
# %config InlineBackend.figure_formats = ['svg']

# %%
plt.figure(figsize=(1.25, 1.25))
plt.scatter(0, 0, s=250, facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().annotate('$s$', (0, 0), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color="k", lw=0.6)
offset = 0.125

s = 0
a = patches.FancyArrowPatch((s+offset, s+offset), (0.5, 0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((s-offset, s+offset), (-0.5, 0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((s+offset, s-offset), (0.5, -0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((s-offset, s-offset), (-0.5, -0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)

plt.gca().annotate(r'$0$', (-0.5, -0.5), ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$\alpha$', (-0.5, 0.5), ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.5, -0.5), ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$1+\alpha+\beta$', (0.5, 0.5), ha='left', va='bottom', fontsize=8)

plt.savefig('figures/bandit2d.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(1.25, 1.25))
plt.scatter(0, 0, s=250, facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().annotate('$s$', (0, 0), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color="k", lw=0.6)
offset = 0.125

s = 0
a = patches.FancyArrowPatch((s+offset, s+offset), (0.5, 0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((s-offset, s+offset), (-0.5, 0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((s+offset, s-offset), (0.5, -0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((s-offset, s-offset), (-0.5, -0.5), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)

plt.gca().annotate(r'$R_{0,0}$', (-0.5, -0.5), ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$R_{0,1}$', (-0.5, 0.5), ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$R_{1,0}$', (0.5, -0.5), ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$R_{1,1}$', (0.5, 0.5), ha='left', va='bottom', fontsize=8)

plt.savefig('figures/bandit2d_Rxy.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(1.25, 1.25/2))
plt.scatter(0, 0, s=10, facecolors='k', edgecolors='k')
plt.axis('off')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color="k", lw=0.6)
offset = 0.1

s = 0
a = patches.FancyArrowPatch((offset, 0), (0.75, 0), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((-offset, 0), (-0.75, 0), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)

plt.gca().annotate(r'$\mathcal{A}_{\mathrm{x}}$', (0, 0.2), ha='center', va='bottom', fontsize=10)
plt.gca().annotate(r'$\mathsf{Left}$', (-0.5, 0.2), ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$\mathsf{Right}$', (0.5, 0.2), ha='left', va='bottom', fontsize=8)

plt.savefig('figures/bandit2d_A1.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(1.25/2, 1.25))
plt.scatter(0, 0, s=10, facecolors='k', edgecolors='k')
plt.axis('off')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color="k", lw=0.6)
offset = 0.1

s = 0
a = patches.FancyArrowPatch((0, offset), (0, 0.75), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((0, -offset), (0, -0.75), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)

plt.gca().annotate(r'$\mathcal{A}_{\mathrm{y}}$', (-0.2, 0), ha='right', va='center', fontsize=10)
plt.gca().annotate(r'$\mathsf{Down}$', (0.2, -0.5), ha='left', va='center', fontsize=8)
plt.gca().annotate(r'$\mathsf{Up}$', (0.2, 0.5), ha='left', va='center', fontsize=8)

plt.savefig('figures/bandit2d_A2.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(1.25, 1.25))
plt.scatter(0, 0, s=10, facecolors='k', edgecolors='k')
plt.axis('off')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color="k", lw=0.6)
offset = 0.1

s = 0
a = patches.FancyArrowPatch((offset, offset), (0.6, 0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((-offset, -offset), (-0.6, -0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((-offset, offset), (-0.6, 0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((offset, -offset), (0.6, -0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)

plt.gca().annotate(r'$\mathcal{A}_{\mathrm{x}} \times \mathcal{A}_{\mathrm{y}}$', (0.0, 0.9), ha='center', va='center', fontsize=10)
plt.gca().annotate(r'$[\mathsf{Left},\mathsf{Down}]$', (-0.6, -0.5), ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$[\mathsf{Left},\mathsf{Up}]$', (-0.6, 0.5), ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$[\mathsf{Right},\mathsf{Down}]$', (0.6, -0.5), ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$[\mathsf{Right},\mathsf{Up}]$', (0.6, 0.5), ha='left', va='bottom', fontsize=8)

plt.savefig('figures/bandit2d_A.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(1.25, 1.25))
plt.scatter(0, 0, s=10, facecolors='k', edgecolors='k')
plt.axis('off')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color="k", lw=0.6)
offset = 0.1

s = 0
a = patches.FancyArrowPatch((offset, offset), (0.6, 0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((-offset, -offset), (-0.6, -0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((-offset, offset), (-0.6, 0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((offset, -offset), (0.6, -0.6), connectionstyle="arc3,rad=-0", **kw)
plt.gca().add_patch(a)

plt.gca().annotate(r'$\mathcal{A}_{\mathrm{x}} \times \mathcal{A}_{\mathrm{y}}$', (0.0, 0.9), ha='center', va='center', fontsize=10)
plt.gca().annotate(r'$[0,0]$', (-0.6, -0.5), ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$[0,1]$', (-0.6, 0.5), ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$[1,0]$', (0.6, -0.5), ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$[1,1]$', (0.6, 0.5), ha='left', va='bottom', fontsize=8)

plt.savefig('figures/bandit2d_A_num.pdf', bbox_inches='tight', pad_inches=0)
plt.show()
