# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as mpath

# %%
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['FreeSans']
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble'] = r"""\usepackage{bm}"""
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ## Chain 1D

# %%
plt.figure(figsize=(2,1))

plt.scatter(0, 0, s=400, facecolors='none', edgecolors='k')
plt.scatter(0.75, 0, s=400, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1)
plt.ylim(-0.5, 0.5)

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$s_{0}$', (0, 0), ha='center', va='center')
plt.gca().annotate('$s_{1}$', (0.75, 0), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset*1.3, sr), (0.75-offset*1.25, 0), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc-offset*5, sr), (sc-offset*1.4, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*2, sr+offset*1.55), (sc-offset, sr+offset), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (0.375, 0.05), c='r', ha='center', va='bottom', fontsize=8)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)

plt.savefig('figures/chain1d.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2.25,1))

plt.scatter(0, 0, s=400, facecolors='none', edgecolors='k')
plt.scatter(0.75, 0, s=400, facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.25)
plt.ylim(-0.5, 0.5)

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$s_{0}$', (0, 0), ha='center', va='center')
plt.gca().annotate('$s_{1}$', (0.75, 0), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.11

sr, sc = -0.02, 0
a = patches.FancyArrowPatch((sc+offset*1.3, sr), (0.75-offset*1.25, sr), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)

offset = 0.08

sr, sc = 0.08, 0
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc-offset*5, sr), (sc-offset*1.5, sr+offset*0.1)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*2, sr+offset*1.55), (sc-offset, sr+offset), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0.08, 0.75
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc-offset*5, sr), (sc-offset*1.5, sr+offset*0.1)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*2, sr+offset*1.55), (sc-offset, sr+offset), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

a = patches.PathPatch(mpath.Path([(sc+offset, sr+offset), (sc+offset*3, sr+offset*3), (sc+offset*5, sr), (sc+offset*1.5, sr+offset*0.1)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*2, sr+offset*1.55), (sc+offset, sr+offset), connectionstyle="arc3,rad=.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate('$+1$', (0.25, 0.0), c='r', ha='center', va='bottom', fontsize=8)

plt.gca().annotate(r'$a = 0$', (-0.175, 0.05), ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$a = 1$', (0.15, -0.05), ha='left', va='top', fontsize=8)

plt.gca().annotate(r'$a = 0$', (0.7, 0.4), ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$a = 1$', (0.8, 0.4), ha='left', va='top', fontsize=8)

plt.savefig('figures/chain1d_full.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ## Chain 2D

# %%
plt.figure(figsize=(3,3))

plt.scatter(0, 0, s=500, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=500, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=500, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=500, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)



plt.gca().annotate('$+1$', (0.5, -offset*2.2), c='r', ha='right', va='top', fontsize=8)
plt.gca().annotate('$+1$', (-offset*2.2, 0.5), c='r', ha='right', va='top', fontsize=8)
plt.gca().annotate('$+1$', (1-offset*1.3, 0.5), c='r', ha='left', va='top', fontsize=8)
plt.gca().annotate('$+1$', (1+offset*2, 0.5), c='r', ha='left', va='top', fontsize=8)
plt.gca().annotate('$+1$', (0.5, 1-offset*1.3), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate('$+1$', (0.5, 1+offset*2), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate('$+2$', (0.5-offset, 0.5-offset),  c='r', ha='left',  va='top', fontsize=8)

plt.savefig('figures/chain2d.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(3.75, 3.75))

plt.scatter(0, 0, s=500, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=500, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=500, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=500, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-1., 1.5)
plt.ylim(-1., 1.5)

plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate('$+1$', (0.5, -offset*2.2), c='r', ha='right', va='top', fontsize=8)
plt.gca().annotate('$+1$', (-offset*2.2, 0.5), c='r', ha='right', va='top', fontsize=8)
plt.gca().annotate('$+1$', (1-offset*1.3, 0.5), c='r', ha='left', va='top', fontsize=8)
plt.gca().annotate('$+1$', (1+offset*2, 0.5), c='r', ha='left', va='top', fontsize=8)
plt.gca().annotate('$+1$', (0.5, 1-offset*1.3), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate('$+1$', (0.5, 1+offset*2), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate('$+2$', (0.5-offset, 0.5-offset),  c='r', ha='left',  va='top', fontsize=8)



## Horizontal Chain
sub_offset = -0.8

plt.scatter(0, sub_offset, s=400, facecolors='none', edgecolors='k')
plt.scatter(1, sub_offset, s=400, marker='s', facecolors='none', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$s_{0,?}$', (0, sub_offset), ha='center', va='center')
plt.gca().annotate('$s_{1,?}$', (1, sub_offset), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = sub_offset, 0
a = patches.FancyArrowPatch((sc+offset*1.3, sr), (1-offset*1.25, sr), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc-offset*5, sr), (sc-offset*1.2, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*1.8, sr+offset*1.5), (sc-offset*0.8, sr+offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (0.45, sub_offset-0.02), c='r', ha='center', va='top', fontsize=8)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)


## Vertical Chain
sub_offset = -0.8

plt.scatter(sub_offset, 0, s=400, facecolors='none', edgecolors='k')
plt.scatter(sub_offset, 1, s=400, marker='s', facecolors='none', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$s_{?,0}$', (sub_offset, 0), ha='center', va='center')
plt.gca().annotate('$s_{?,1}$', (sub_offset, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, sub_offset
a = patches.FancyArrowPatch((sc, sr+offset*1.3), (sc, 1-offset*1.25), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*5), (sc, sr-offset*1.2)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*1.5, sr-offset*1.8), (sc-offset*0.8, sr-offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (sub_offset-0.02, 0.45), c='r', ha='right', va='center', fontsize=8)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)

plt.plot([-0.5, -0.5], [-1, 1.5], c='gray', lw=0.5)
plt.plot([-1, 1.5], [-0.5, -0.5], c='gray', lw=0.5)
plt.plot([-0.5, -0.95], [-0.5, -0.95], c='gray', lw=0.5)
plt.gca().annotate(r'$\mathcal{M}_{\mathrm{x}}$', (-0.65, -0.85), ha='center', va='center', fontsize=10)
plt.gca().annotate(r'$\mathcal{M}_{\mathrm{y}}$', (-0.85, -0.65), ha='center', va='center', fontsize=10)

plt.savefig('figures/chain2d_factored.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(3.75, 3.75))

plt.scatter(0, 0, s=500, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=500, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=500, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=500, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-1., 1.5)
plt.ylim(-1., 1.5)

plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate('$+1$', (0.5, -offset*2.2), c='r', ha='right', va='top', fontsize=8)
plt.gca().annotate('$+1$', (-offset*2.2, 0.5), c='r', ha='right', va='top', fontsize=8)
plt.gca().annotate('$+1$', (1-offset*1.3, 0.5), c='r', ha='left', va='top', fontsize=8)
plt.gca().annotate('$+1$', (1+offset*2, 0.5), c='r', ha='left', va='top', fontsize=8)
plt.gca().annotate('$+1$', (0.5, 1-offset*1.3), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate('$+1$', (0.5, 1+offset*2), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate('$+2$', (0.5-offset, 0.5-offset),  c='r', ha='left',  va='top', fontsize=8)



## Horizontal Chain
sub_offset = -0.8

plt.scatter(0, sub_offset, s=400, facecolors='#ffee6e', edgecolors='k')
plt.scatter(1, sub_offset, s=400, marker='s', facecolors='#80ff80', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$s_{0,?}$', (0, sub_offset), ha='center', va='center')
plt.gca().annotate('$s_{1,?}$', (1, sub_offset), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = sub_offset, 0
a = patches.FancyArrowPatch((sc+offset*1.3, sr), (1-offset*1.25, sr), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc-offset*5, sr), (sc-offset*1.2, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*1.8, sr+offset*1.5), (sc-offset*0.8, sr+offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (0.45, sub_offset-0.02), c='r', ha='center', va='top', fontsize=8)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)


## Vertical Chain
sub_offset = -0.8

plt.scatter(sub_offset, 0, s=400, facecolors='#6fdaf8', edgecolors='k')
plt.scatter(sub_offset, 1, s=400, marker='s', facecolors='#ffabff', edgecolors='k')

# state index (row, col)
# plot coords (col, row)
plt.gca().annotate('$s_{?,0}$', (sub_offset, 0), ha='center', va='center')
plt.gca().annotate('$s_{?,1}$', (sub_offset, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, sub_offset
a = patches.FancyArrowPatch((sc, sr+offset*1.3), (sc, 1-offset*1.25), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*5), (sc, sr-offset*1.2)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*1.5, sr-offset*1.8), (sc-offset*0.8, sr-offset*0.8), connectionstyle="arc3,rad=-.2", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate('$+1$', (sub_offset-0.02, 0.45), c='r', ha='right', va='center', fontsize=8)

# plt.gca().annotate(r'$a = \mathsf{L}$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = \mathsf{R}$', (0.15, -0.1), ha='left', va='top', fontsize=8)

# plt.gca().annotate(r'$a = 0$', (-0.15, -0.1), ha='right', va='top', fontsize=8)
# plt.gca().annotate(r'$a = 1$', (0.15, -0.1), ha='left', va='top', fontsize=8)

plt.plot([-0.5, -0.5], [-1, 1.5], c='gray', lw=0.5)
plt.plot([-1, 1.5], [-0.5, -0.5], c='gray', lw=0.5)
plt.plot([-0.5, -0.95], [-0.5, -0.95], c='gray', lw=0.5)
plt.gca().annotate(r'$\mathcal{M}_{\mathrm{x}}$', (-0.65, -0.85), ha='center', va='center', fontsize=10)
plt.gca().annotate(r'$\mathcal{M}_{\mathrm{y}}$', (-0.85, -0.65), ha='center', va='center', fontsize=10)

plt.savefig('figures/chain2d_factored_color.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.savefig('figures/chain2d_clean.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ### Sufficient

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.8$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1.9$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π444.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$0.9$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π224.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$0$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.1, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π123.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ### Violate policy

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.71$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1.9$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π244.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.8$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.1, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π424.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$0$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1.9$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π144.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.71$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π324.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$0.9$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.1, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π313.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.8$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π423.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$0$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1.9$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π143.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ### Violate transition

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
# a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
# plt.gca().add_patch(a)

a = patches.PathPatch(mpath.Path([(sc+offset, sr+offset), (sc+offset*3, sr+offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr+offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.8$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)

plt.gca().add_patch(patches.Rectangle((0.1, 0.85), 0.5, 0.35, edgecolor='none', facecolor='Gold', alpha=0.35, zorder=0, clip_on=False))


plt.savefig('figures/chain2d_p_π444.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
# a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
# plt.gca().add_patch(a)

a = patches.PathPatch(mpath.Path([(sc+offset, sr+offset), (sc+offset*3, sr+offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr+offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)

a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.8$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)

plt.gca().add_patch(patches.Rectangle((0.1, 0.85), 0.5, 0.35, edgecolor='none', facecolor='Gold', alpha=0.35, zorder=0, clip_on=False))


# plt.savefig('figures/chain2d_p_π444.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='b', lw=1.8, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$0$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.1, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)


plt.savefig('figures/chain2d_π113.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
# a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
# plt.gca().add_patch(a)

a = patches.PathPatch(mpath.Path([(sc+offset, sr+offset), (sc+offset*3, sr+offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr+offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

plt.gca().annotate(r'$+1$', (0.45, -0.25), c='r', ha='center', va='top', fontsize=8)
plt.gca().annotate(r'$+1$', (0.45, 0.8), c='r', ha='center', va='top', fontsize=8)
plt.gca().annotate(r'$+1$', (-0.25, 0.3), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$+1$', (0.85, 0.3), c='r', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$+1$', (1.2, 0.45), c='r', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$+2$', (0.3, 0.3), c='r', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$(1-\gamma)$', (0.2, 1.2), c='r', ha='left', va='bottom', fontsize=8)

plt.savefig('figures/chain2d_counterexample_clean.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
# a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
# plt.gca().add_patch(a)

a = patches.PathPatch(mpath.Path([(sc+offset, sr+offset), (sc+offset*3, sr+offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), color='b', fill=False, lw=1.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr+offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.3, lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.3, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", arrowstyle=style, color='b', lw=1.8, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.3, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.3, color='k', lw=0, shrinkA=6, shrinkB=0)
plt.gca().add_patch(a)


plt.gca().annotate(r'$1.8$', (-0.2, -0.2), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1.9$', (-0.2, 0.15), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1.9$', (0.05, -0.2), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$2$', (0.15, 0.15), c='blue', ha='right', va='bottom', fontsize=8)

plt.gca().annotate(r'$0$', (0.9, -0.3), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$0$', (1.4, -0.2), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.9, 0.3), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (1.2, 0.3), c='blue', ha='left', va='top', fontsize=8)

plt.gca().annotate(r'$0.9$', (-0.25, 0.85), c='blue', ha='right', va='top', fontsize=8)
plt.gca().annotate(r'$1$', (0.1, 0.85), c='blue', ha='left', va='top', fontsize=8)
plt.gca().annotate(r'$0.9$', (-0.15, 1.2), c='blue', ha='right', va='bottom', fontsize=8)
plt.gca().annotate(r'$1$', (0.15, 1.2), c='blue', ha='left', va='bottom', fontsize=8)

plt.savefig('figures/chain2d_counterexample.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(2,2))

plt.scatter(0, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(0, 1, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 0, s=200, facecolors='none', edgecolors='k')
plt.scatter(1, 1, s=200, marker='s', facecolors='none', edgecolors='k')
plt.axis('off')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

# plt.gca().annotate('$s_{0,0}$', (0, 0), ha='center', va='center')
# plt.gca().annotate('$s_{0,1}$', (0, 1), ha='center', va='center')
# plt.gca().annotate('$s_{1,0}$', (1, 0), ha='center', va='center')
# plt.gca().annotate('$s_{1,1}$', (1, 1), ha='center', va='center')

style="Simple,tail_width=0.2,head_width=3,head_length=5"
kw = dict(arrowstyle=style, color='k', lw=0.6, shrinkA=0, shrinkB=0)
offset = 0.1

sr, sc = 0, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=0", alpha=0.2, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset), (0, 1-offset-0.05), connectionstyle="arc3,rad=-.4", alpha=0.2, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 0), connectionstyle="arc3,rad=.4", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.2, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.2, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 1, 0
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1-offset-0.05, 1+offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.2, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr-offset), (1-offset-0.05, 1-offset+0.05), connectionstyle="arc3,rad=.25", alpha=0.2, **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc-offset*4, sr), (sc-offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.2, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset*3, sr-offset), (sc-offset*1.25, sr), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', alpha=0.2, lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr+offset), (sc-offset*3, sr+offset*3), (sc, sr+offset*4), (sc, sr+offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr+offset*3), (sc, sr+offset*1.25), connectionstyle="arc3,rad=-.4", arrowstyle=style, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)


sr, sc = 0, 1
a = patches.FancyArrowPatch((sc-offset, sr+offset), (1-offset+0.05, 1-offset-0.05), connectionstyle="arc3,rad=-.25", alpha=0.2, **kw)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset, sr+offset), (1+offset-0.05, 1-offset-0.05), connectionstyle="arc3,rad=.25", **kw)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc-offset, sr-offset), (sc-offset*3, sr-offset*3), (sc, sr-offset*4), (sc, sr-offset*1.5)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.2, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc-offset, sr-offset*3), (sc, sr-offset*1.25), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.2, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)
a = patches.PathPatch(mpath.Path([(sc+offset, sr-offset), (sc+offset*3, sr-offset*3), (sc+offset*4, sr), (sc+offset*1.5, sr)],
         [mpath.Path.MOVETO, mpath.Path.CURVE4, mpath.Path.CURVE4, mpath.Path.CURVE4]), alpha=0.2, fill=False, lw=0.8)
plt.gca().add_patch(a)
a = patches.FancyArrowPatch((sc+offset*3, sr-offset), (sc+offset*1.25, sr), connectionstyle="arc3,rad=.4", arrowstyle=style, alpha=0.2, color='k', lw=0, shrinkA=0, shrinkB=0)
plt.gca().add_patch(a)

# plt.savefig('figures/chain2d_π243.pdf', bbox_inches='tight', pad_inches=0)
plt.show()
